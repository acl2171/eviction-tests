# %%
import pandas as pd
import numpy as np

# %%
evict = pd.read_csv('../data/evictMerge.csv')
evict = evict.loc[evict.year == 2016]
evict.head()
# Out:
#           GEOID  year  name                             parent-location  \
# 16  11001000100  2016  1.00  District of Columbia, District of Columbia
# 33  11001000201  2016  2.01  District of Columbia, District of Columbia
# 50  11001000202  2016  2.02  District of Columbia, District of Columbia
# 67  11001000300  2016  3.00  District of Columbia, District of Columbia
# 84  11001000400  2016  4.00  District of Columbia, District of Columbia
#
#     population  poverty-rate  renter-occupied-households  pct-renter-occupied  \
# 16      5209.0          0.00                      1380.0                44.52
# 33      3685.0          0.00                         1.0                 0.00
# 50      4817.0          1.44                       997.0                35.73
# 67      6095.0          0.00                      1605.0                52.06
# 84      1578.0          3.36                       237.0                36.00
#
# ...

# %%
ward8 = list(set([11001007301, 11001007401, 11001007601, 11001007503, 
         11001007504, 11001007502, 11001007408, 11001007403, 
         11001007409, 11001007304, 11001009804, 11001009700, 
         11001009801, 11001009802, 11001009811, 11001009810, 
         11001010900, 11001009807, 11001007301, 11001009802, 
         11001009801, 11001009803, 11001009700, 11001010400, 
         11001007304, 11001007409, 11001007403, 11001007404, 
         11001007406, 11001007408, 11001007502, 11001007407,
         11001007406, 11001007401, 11001007503, 11001007504, 
         11001007502, 11001007601]))

# %%
ward8
# Out:
# [11001009801,
#  11001009802,
#  11001009803,
#  11001009804,
#  11001007502,
#  11001007503,
#  11001007504,
#  11001009807,
#  11001009810,
#  11001009811,
#  11001009700,
#  11001007401,
#  11001007403,
#  11001007404,
#  11001007406,
#  11001007407,
#  11001007408,
#  11001007409,
#  11001007301,
#  11001007304,
#  11001010900,
#  11001010400,
#  11001007601]

# %%
evict['ward8'] = [[1 if x == el for el in ward8 for x in evict['GEOID']]]
# Out:
#   File "<ipython-input-85-8c2fa2ba7e7c>", line 1
#     evict['ward8'] = [[1 if x == el for el in ward8 for x in evict['GEOID']]]
#                                       ^
# SyntaxError: invalid syntax

# %%
evict
# Out:
#             GEOID  year    name                             parent-location  \
# 16    11001000100  2016    1.00  District of Columbia, District of Columbia
# 33    11001000201  2016    2.01  District of Columbia, District of Columbia
# 50    11001000202  2016    2.02  District of Columbia, District of Columbia
# 67    11001000300  2016    3.00  District of Columbia, District of Columbia
# 84    11001000400  2016    4.00  District of Columbia, District of Columbia
# 101   11001000501  2016    5.01  District of Columbia, District of Columbia
# 118   11001000502  2016    5.02  District of Columbia, District of Columbia
# 135   11001000600  2016    6.00  District of Columbia, District of Columbia
# 152   11001000701  2016    7.01  District of Columbia, District of Columbia
# 169   11001000702  2016    7.02  District of Columbia, District of Columbia
# 186   11001000801  2016    8.01  District of Columbia, District of Columbia
# ...

# %%
evict
# Out:
#             GEOID  year    name                             parent-location  \
# 16    11001000100  2016    1.00  District of Columbia, District of Columbia
# 33    11001000201  2016    2.01  District of Columbia, District of Columbia
# 50    11001000202  2016    2.02  District of Columbia, District of Columbia
# 67    11001000300  2016    3.00  District of Columbia, District of Columbia
# 84    11001000400  2016    4.00  District of Columbia, District of Columbia
# 101   11001000501  2016    5.01  District of Columbia, District of Columbia
# 118   11001000502  2016    5.02  District of Columbia, District of Columbia
# 135   11001000600  2016    6.00  District of Columbia, District of Columbia
# 152   11001000701  2016    7.01  District of Columbia, District of Columbia
# 169   11001000702  2016    7.02  District of Columbia, District of Columbia
# 186   11001000801  2016    8.01  District of Columbia, District of Columbia
# ...

# %%
# Out:
#             GEOID  year    name                             parent-location  \
# 1563  11001007301  2016   73.01  District of Columbia, District of Columbia
# 1580  11001007304  2016   73.04  District of Columbia, District of Columbia
# 1597  11001007401  2016   74.01  District of Columbia, District of Columbia
# 1614  11001007403  2016   74.03  District of Columbia, District of Columbia
# 1631  11001007404  2016   74.04  District of Columbia, District of Columbia
# 1648  11001007406  2016   74.06  District of Columbia, District of Columbia
# 1665  11001007407  2016   74.07  District of Columbia, District of Columbia
# 1682  11001007408  2016   74.08  District of Columbia, District of Columbia
# 1699  11001007409  2016   74.09  District of Columbia, District of Columbia
# 1716  11001007502  2016   75.02  District of Columbia, District of Columbia
# 1733  11001007503  2016   75.03  District of Columbia, District of Columbia
# ...

# %%
ward8df = evict.loc[(evict.GEOID == 11001007301) | 
          (evict.GEOID == 11001007304) |
          (evict.GEOID == 11001007401) | 
          (evict.GEOID == 11001007403) | 
          (evict.GEOID == 11001007404) |
          (evict.GEOID == 11001007406) |
          (evict.GEOID == 11001007407) |
          (evict.GEOID == 11001007408) |
          (evict.GEOID == 11001007409) |
          (evict.GEOID == 11001007502) |
          (evict.GEOID == 11001007503) |
          (evict.GEOID == 11001007504) |
          (evict.GEOID == 11001007601) |
          (evict.GEOID == 11001009700) |
          (evict.GEOID == 11001009801) |
          (evict.GEOID == 11001009802) |
          (evict.GEOID == 11001009803) |
          (evict.GEOID == 11001009804) |
          (evict.GEOID == 11001009807) |
          (evict.GEOID == 11001009810) |
          (evict.GEOID == 11001009811) |
          (evict.GEOID == 11001010400) |
          (evict.GEOID == 11001010900)]

# %%
puds = pd.read_csv('../data/OpenData/Planned_Unit_Development_PUDs.csv')

# %%
ward8puds2 = puds.loc[(puds.OBJECTID == 66488) |
                     (puds.OBJECTID == 66490) |
                     (puds.OBJECTID == 66368) |
                     (puds.OBJECTID == 66502) |
                     (puds.OBJECTID == 66478)]

# %%
ward8puds2['GEOID'] = np.nan
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ward8puds2['GEOID'].loc[ward8puds2.OBJECTID == 66478] = 11001009807
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ward8pudsdf = pd.concat([ward8puds, ward8puds2])

# %%
ward8pudsdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-ada372b33dc7> in <module>
# ----> 1 ward8pudsdf
#
# NameError: name 'ward8pudsdf' is not defined

# %%
ward8pudsdf.count()
# Out:
# OBJECTID                22
# PUD_NAME                22
# PUD_WEB_URL             22
# PUD_CHANGE_NARRATIVE    22
# PUD_ZONING              22
# PUD_STATUS              22
# PUD_CASE_NUMBER         22
# SHAPEAREA               22
# SHAPELEN                22
# GLOBALID                22
# WARD                    22
# GEOID                   22
# dtype: int64

# %%
ward8df2 = ward8df.merge(ward8pudsdf, on='GEOID', how='outer')

# %%
ward8df2[['GEOID', 'pct-white','poverty-rate', 'renter-occupied-households']]
# Out:
#           GEOID  pct-white  poverty-rate  renter-occupied-households
# 0   11001007301      61.02          3.29                      1021.0
# 1   11001007304       3.47         38.02                       974.0
# 2   11001007401       0.20         58.38                       761.0
# 3   11001007401       0.20         58.38                       761.0
# 4   11001007403       1.23         26.65                       968.0
# 5   11001007404       0.71         38.26                       949.0
# 6   11001007406       0.00         28.96                       946.0
# 7   11001007407       0.84         24.35                       833.0
# 8   11001007407       0.84         24.35                       833.0
# 9   11001007408       0.85         45.09                       916.0
# 10  11001007409       0.66         35.70                      1152.0
# 11  11001007502       1.04         48.96                      1412.0
# 12  11001007503       1.45         44.82                       621.0
# ...
