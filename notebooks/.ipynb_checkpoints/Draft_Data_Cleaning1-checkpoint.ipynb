# %%
import pandas as pd

# %%
evict = pd.read_csv('../data/EvictionLab/tracts.csv')

# %%
ward8 = [11001009801,11001009802,11001009803,11001009804,11001007502,11001007503,
         11001007504,11001009807,11001009810,11001009811,11001009700,11001007401,
         11001007403,11001007404,11001007406,11001007407,11001007408,11001007409,
         11001007301,11001007304, 11001010900,11001010400,11001007601]

# %%
evict.head()
# Out:
#          GEOID  year  name                             parent-location  \
# 0  11001000100  2000   1.0  District of Columbia, District of Columbia
# 1  11001000100  2001   1.0  District of Columbia, District of Columbia
# 2  11001000100  2002   1.0  District of Columbia, District of Columbia
# 3  11001000100  2003   1.0  District of Columbia, District of Columbia
# 4  11001000100  2004   1.0  District of Columbia, District of Columbia
#
#    population  poverty-rate  renter-occupied-households  pct-renter-occupied  \
# 0      4674.0           5.2                      1279.0                46.95
# 1      4674.0           5.2                      1275.0                46.95
# 2      4674.0           5.2                      1272.0                46.95
# 3      4674.0           5.2                      1268.0                46.95
# 4      4674.0           5.2                      1265.0                46.95
#
# ...

# %%
def clean_eviction_data(df, GEOIDs_list):
    df = df.loc[df.year == 2016]
    df = df.loc[df['GEOID'].isin(GEOIDs_list)]
    df.reset_index(inplace=True)
    return df

# %%
clean_eviction_data(evict, ward8)
# Out:
#     index        GEOID  year    name  \
# 0    1563  11001007301  2016   73.01
# 1    1580  11001007304  2016   73.04
# 2    1597  11001007401  2016   74.01
# 3    1614  11001007403  2016   74.03
# 4    1631  11001007404  2016   74.04
# 5    1648  11001007406  2016   74.06
# 6    1665  11001007407  2016   74.07
# 7    1682  11001007408  2016   74.08
# 8    1699  11001007409  2016   74.09
# 9    1716  11001007502  2016   75.02
# 10   1733  11001007503  2016   75.03
# 11   1750  11001007504  2016   75.04
# 12   1767  11001007601  2016   76.01
# 13   2617  11001009700  2016   97.00
# 14   2634  11001009801  2016   98.01
# 15   2651  11001009802  2016   98.02
# 16   2668  11001009803  2016   98.03
# 17   2685  11001009804  2016   98.04
# 18   2702  11001009807  2016   98.07
# 19   2719  11001009810  2016   98.10
# 20   2736  11001009811  2016   98.11
# 21   2923  11001010400  2016  104.00
# 22   3008  11001010900  2016  109.00
#
# ...

# %%
puds = pd.read_csv('../data/OpenData/Planned_Unit_Development_PUDs.csv')

# %%
puds.head()
# Out:
#    OBJECTID                            PUD_NAME  \
# 0     66397  3rd & M and Park Inn Associates LP
# 1     66398                       Lowell School
# 2     66399              Prospect Joint Venture
# 3     66400       Unified Communications Center
# 4     66401                   Matthews Memorial
#
#                                          PUD_WEB_URL  \
# 0  https://app.dcoz.dc.gov/Content/Search/ViewCas...
# 1  https://app.dcoz.dc.gov/Content/Search/ViewCas...
# 2  https://app.dcoz.dc.gov/Content/Search/ViewCas...
# 3  https://app.dcoz.dc.gov/Content/Search/ViewCas...
# 4  https://app.dcoz.dc.gov/Content/Search/ViewCas...
#
#                                 PUD_CHANGE_NARRATIVE PUD_ZONING PUD_STATUS  \
# 0  Official Digital Zoning Map of July 1, 2010, A...      R-5-D      Final
# 1  Official Digital Zoning Map of July 1, 2010, D...      R-1-A      Final
# 2        Official Digital Zoning Map of July 1, 2010      R-5-A      Final
# ...

# %%
crosswalk = pd.read_csv('../data/ward8PUDcrosswalk.csv')

# %%
crosswalk.head()
# Out:
#    OBJECTID                           PUD_NAME        GEOID
# 0   66488.0              Brownstein Commons LP  11001007304
# 1   66401.0                  Matthews Memorial  11001007401
# 2   66447.0              Poplar Point RBBR LLC  11001007401
# 3   66199.0           Fredrick Douglas Stanton  11001007404
# 4   66402.0  Sheridan Redevelopment LLC & DCHA  11001007406

# %%
puds = puds.merge(crosswalk[['OBJECTID','GEOID']], on='OBJECTID')

# %%
evict.merge(puds, on='GEOID')
# Out:
#            GEOID  year    name                             parent-location  \
# 0    11001007304  2000   73.04  District of Columbia, District of Columbia
# 1    11001007304  2001   73.04  District of Columbia, District of Columbia
# 2    11001007304  2002   73.04  District of Columbia, District of Columbia
# 3    11001007304  2003   73.04  District of Columbia, District of Columbia
# 4    11001007304  2004   73.04  District of Columbia, District of Columbia
# 5    11001007304  2005   73.04  District of Columbia, District of Columbia
# 6    11001007304  2006   73.04  District of Columbia, District of Columbia
# 7    11001007304  2007   73.04  District of Columbia, District of Columbia
# 8    11001007304  2008   73.04  District of Columbia, District of Columbia
# 9    11001007304  2009   73.04  District of Columbia, District of Columbia
# 10   11001007304  2010   73.04  District of Columbia, District of Columbia
# ...
