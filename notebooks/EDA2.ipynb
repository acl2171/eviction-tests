# %%
import pandas as pd
import numpy as np
import geopandas

# %%
evict = pd.read_csv('../data/evictMerge.csv')
evict16 = evict.loc[evict.year == 2016]
evict16.head()
# Out:
#           GEOID  year  name                             parent-location  \
# 16  11001000100  2016  1.00  District of Columbia, District of Columbia
# 33  11001000201  2016  2.01  District of Columbia, District of Columbia
# 50  11001000202  2016  2.02  District of Columbia, District of Columbia
# 67  11001000300  2016  3.00  District of Columbia, District of Columbia
# 84  11001000400  2016  4.00  District of Columbia, District of Columbia
#
#     population  poverty-rate  renter-occupied-households  pct-renter-occupied  \
# 16      5209.0          0.00                      1380.0                44.52
# 33      3685.0          0.00                         1.0                 0.00
# 50      4817.0          1.44                       997.0                35.73
# 67      6095.0          0.00                      1605.0                52.06
# 84      1578.0          3.36                       237.0                36.00
#
# ...

# %%
evict16['ward'] = np.nan
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
evict16['ward'].loc[evict16.GEOID == 11001000100] = '2'
# Out:
# /Users/flatironschool/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
evict16.loc[evict16.GEOID == 11001000100]
# Out:
#           GEOID  year  name                             parent-location  \
# 16  11001000100  2016   1.0  District of Columbia, District of Columbia
#
#     population  poverty-rate  renter-occupied-households  pct-renter-occupied  \
# 16      5209.0           0.0                      1380.0                44.52
#
#     median-gross-rent  median-household-income  ...  POP100  HU100  AREALAND  \
# 16             1981.0                 175048.0  ...   324.0  207.0  576053.0
#
#     AREAWATER  UR    CENTLAT    CENTLON   INTPTLAT   INTPTLON  ward
# 16        NaN   U  38.915067 -77.061109  38.915067 -77.061109     2
#
# [1 rows x 48 columns]

# %%
pd.read_csv('../data/OpenData/Planned_Unit_Development_PUDs.csv')
# Out:
#      OBJECTID                                           PUD_NAME  \
# 0       66397                 3rd & M and Park Inn Associates LP
# 1       66398                                      Lowell School
# 2       66399                             Prospect Joint Venture
# 3       66400                      Unified Communications Center
# 4       66401                                  Matthews Memorial
# 5       66402                  Sheridan Redevelopment LLC & DCHA
# 6       66403                                  Alpine Associates
# 7       66404                       Parcel Seven Associates LLC
# 8       66405                               Stanton-Eastbanc LLC
# 9       66406                                     Salvation Army
# 10      66407                                       Jemals Babes
# 11      66408  Mid-City Financial Corporation & Brentwood Ass...
# 12      66409      M St Dev Group LLC & Square 772 Dev Group LLC
# ...
